# %% [markdown]
# <a href="https://colab.research.google.com/github/paomianzenmezhuhaochi/BC_yolo/blob/main/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BC_Yolov8')

# %%
# %cd /content/drive/MyDrive/BC_Yolov8
# Out:
# /content

# %% [markdown]
# # 初次需运行

# %%
# !git clone https://github.com/paomianzenmezhuhaochi/BC_yolo.git
# Out:
# fatal: destination path 'BC_yolo' already exists and is not an empty directory.

# %%
# !pip install tensorboard
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.

# %%
# %cd BC_yolo
# Out:
# /content/drive/.shortcut-targets-by-id/10mmY3vo3eaz-SZ096aXs7ixbfOJtt1yq/BC_Yolov8/BC_yolo

# %%
# !pip install -e ultralytics/
# Out:
# Obtaining file:///content/drive/.shortcut-targets-by-id/10mmY3vo3eaz-SZ096aXs7ixbfOJtt1yq/BC_Yolov8/BC_yolo/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.204-0.editable-py3-none-any.whl size=23238 sha256=a1252d7148c964ae81da014a8c44fe273a9cd42e4c2aa389f1b1b5f535b4a5f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d2pw47w3/wheels/39/fe/ba/84be1fa476dfff7c332724e2abb66bcafc9c5e85380561435b
# Successfully built ultralytics
# ...

# %%
# !yolo settings tensorboard=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Updated 'tensorboard=True'
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/drive/.shortcut-targets-by-id/10mmY3vo3eaz-SZ096aXs7ixbfOJtt1yq/BC_Yolov8/datasets",
#   "weights_dir": "/content/drive/.shortcut-targets-by-id/10mmY3vo3eaz-SZ096aXs7ixbfOJtt1yq/BC_Yolov8/BC_yolo/weights",
#   "runs_dir": "/content/drive/.shortcut-targets-by-id/10mmY3vo3eaz-SZ096aXs7ixbfOJtt1yq/BC_Yolov8/BC_yolo/runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
# ...

# %%
# !pip install patched_yolo_infer

# %% [markdown]
# # Train

# %%
# !python data_process/crop_data.py
# Out:
# 没有对应标签的图片(1):
#    ISICDM2025_000130 (1)
# 没有对应图片的标签(14):
#    ISICDM2025_000514 (1)
#    ISICDM2025_000516 (1)
#    ISICDM2025_000517 (1)
#    ISICDM2025_000518 (1)
#    ISICDM2025_000519 (1)
#    ISICDM2025_000520 (1)
#    ISICDM2025_000522 (1)
#    ISICDM2025_000523 (1)
#    ISICDM2025_000524 (1)
#    ISICDM2025_000525 (1)
#    ISICDM2025_000526 (1)
#    ISICDM2025_000527 (1)
#    ISICDM2025_000528 (1)
#    ISICDM2025_000646 (1)
# 开始处理 680 对图像/标签 ...
#   进度: 50/680 (7.4%)
#   进度: 100/680 (14.7%)
#   进度: 150/680 (22.1%)
#   进度: 200/680 (29.4%)
#   进度: 250/680 (36.8%)
#   进度: 300/680 (44.1%)
#   进度: 350/680 (51.5%)
#   进度: 400/680 (58.8%)
#   进度: 450/680 (66.2%)
#   进度: 500/680 (73.5%)
#   进度: 550/680 (80.9%)
#   进度: 600/680 (88.2%)
#   进度: 650/680 (95.6%)
#   进度: 680/680 (100.0%)
# 处理完成。成功处理 680 张。

# %%
# !python scripts/train.py
# Out:
# New https://pypi.org/project/ultralytics/8.3.206 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !python scripts/train_3.py
# Out:
# New https://pypi.org/project/ultralytics/8.3.206 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !python scripts/train_resume.py
# Out:
# New https://pypi.org/project/ultralytics/8.3.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Infer

# %%
import os
import cv2
from ultralytics import YOLO
import json
from typing import List, Dict, Any, Optional
from datetime import datetime

from patched_yolo_infer import (
    MakeCropsDetectThem,
    CombineDetections,
    visualize_results,  # 可用于带 patch 可视化
    visualize_results_usual_yolo_inference,  # 非 patch 可视化
)

def predict_on_folder(folder_path: str, model_path: str, json_output_path: str):
    """
    Predicts on all PNG images in a folder and saves the results to a JSON file.

    Args:
        folder_path (str): Path to the folder containing PNG images.
        model_path (str): Path to the YOLO model weights.
        json_output_path (str): Path to the output JSON file.
    """

    all_predictions = []

    for filename in os.listdir(folder_path):
        if filename.endswith(".png"):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)

            if img is None:
                print(f"Warning: Could not read image {img_path}")
                continue

            # Get image dimensions
            img_height, img_width, _ = img.shape

            element_crops = MakeCropsDetectThem(
                image=img,
                model_path=model_path,
                segment=False,
                show_crops=False,
                shape_x=1024,
                shape_y=1024,
                overlap_x=50,
                overlap_y=50,
                conf=0.05,
                iou=0.7,
                classes_list=[0, 1, 2, 3, 5, 7],
                show_processing_status=True
            )
            result = CombineDetections(element_crops, match_metric="IOU",class_agnostic_nms=False,nms_threshold=0.05)

            # Process results for JSON output
            for det in result:
                # det format from CombineDetections is [x1, y1, x2, y2, confidence, class_id] in absolute coordinates
                x1, y1, x2, y2, confidence, class_id = det
                bbox_width = x2 - x1
                bbox_height = y2 - y1
                bbox = [float(x1), float(y1), float(bbox_width), float(bbox_height)] # [x, y, width, height] - top-left corner + width and height

                prediction = {
                    "image_id": filename,
                    "category_id": int(class_id),
                    "bbox": bbox,
                    "score": float(confidence),
                }
                all_predictions.append(prediction)

            print(f"Processed: {filename}")

    # Save all predictions to a single JSON file
    with open(json_output_path, 'w') as f:
        json.dump(all_predictions, f, indent=4)

    print(f"Saved predictions to JSON: {json_output_path}")

# %%
# usage:
input_folder = '/content/drive/MyDrive/BC_Yolov8/test_images' # Replace with your input folder path
model_weights_path = 'runs/stage3/weights/best.pt' # Ensure this path is correct relative to your working directory
json_output_path = '/content/drive/MyDrive/BC_Yolov8/predictions.json' # Path to save the JSON file

predict_on_folder(input_folder, model_weights_path, json_output_path)
